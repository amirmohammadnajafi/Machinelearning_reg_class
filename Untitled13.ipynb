# %%
import pandas as pd
import statsmodels.api as st
import statsmodels.stats as st1
from statsmodels import regression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
from pandas.plotting import scatter_matrix
import scipy.stats as sciv
import statistics
import random
from pandas.plotting import scatter_matrix
from sklearn import linear_model
from sklearn.cluster import KMeans

# %%
data=pd.read_csv(r"E:\housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.notnull().sum()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
data_kham=data[["longitude","latitude","ocean_proximity"]]

# %%
data_kham["nazdiki"]=data_kham["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})
# Out:
# C:\Users\amiii\AppData\Local\Temp\ipykernel_1956\3365722317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kham["nazdiki"]=data_kham["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})

# %%
data_kham=data_kham.drop(["ocean_proximity"],axis=1)
data_kham
# Out:
#        longitude  latitude  nazdiki
# 0        -122.23     37.88        0
# 1        -122.22     37.86        0
# 2        -122.24     37.85        0
# 3        -122.25     37.85        0
# 4        -122.25     37.85        0
# ...          ...       ...      ...
# 20635    -121.09     39.48        2
# 20636    -121.21     39.49        2
# 20637    -121.22     39.43        2
# 20638    -121.32     39.43        2
# 20639    -121.24     39.37        2
#
# [20640 rows x 3 columns]

# %%
sns.scatterplot(data_kham.longitude,data_kham.latitude)
# Out:
# E:\Users\amiii\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
kmeans=KMeans(98)
kmeans.fit(data_kham)
# Out:
# KMeans(n_clusters=98)

# %%
n=kmeans.fit_predict(data_kham)
n
# Out:
# array([ 0,  0,  0, ..., 97, 97, 97])

# %%
data_kham["clus"]=n

# %%
data_kham
# Out:
#        longitude  latitude  nazdiki  clus
# 0        -122.23     37.88        0     0
# 1        -122.22     37.86        0     0
# 2        -122.24     37.85        0     0
# 3        -122.25     37.85        0     0
# 4        -122.25     37.85        0     0
# ...          ...       ...      ...   ...
# 20635    -121.09     39.48        2    97
# 20636    -121.21     39.49        2    97
# 20637    -121.22     39.43        2    97
# 20638    -121.32     39.43        2    97
# 20639    -121.24     39.37        2    97
#
# [20640 rows x 4 columns]

# %%
data_kham.describe()
# Out:
#           longitude      latitude       nazdiki          clus
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean    -119.569704     35.631861      1.464729     41.592587
# std        2.003532      2.135952      0.854226     29.483423
# min     -124.350000     32.540000      0.000000      0.000000
# 25%     -121.800000     33.930000      1.000000     14.000000
# 50%     -118.490000     34.260000      1.000000     38.000000
# 75%     -118.010000     37.710000      2.000000     63.000000
# max     -114.310000     41.950000      4.000000     97.000000

# %%
plt.scatter(data_kham.longitude,data_kham.latitude,c=data_kham.clus,cmap="rainbow")

# %%
ll=data_kham[data_kham["clus"]==0]

# %%
sns.scatterplot(ll.longitude,ll.latitude)
# Out:
# E:\Users\amiii\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
data1=data

# %%
data1=data1.dropna()

# %%
data1.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
pd.unique(data1.ocean_proximity)
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
data1["ocean_proximity"]=data1["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})
# Out:
# C:\Users\amiii\AppData\Local\Temp\ipykernel_1956\3189185016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["ocean_proximity"]=data1["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})

# %%
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataplot=data1[["longitude","latitude","ocean_proximity"]]

# %%
dataplot
# Out:
#        longitude  latitude  ocean_proximity
# 0        -122.23     37.88                0
# 1        -122.22     37.86                0
# 2        -122.24     37.85                0
# 3        -122.25     37.85                0
# 4        -122.25     37.85                0
# ...          ...       ...              ...
# 20635    -121.09     39.48                2
# 20636    -121.21     39.49                2
# 20637    -121.22     39.43                2
# 20638    -121.32     39.43                2
# 20639    -121.24     39.37                2
#
# [20433 rows x 3 columns]

# %%
plt.scatter(dataplot.longitude,dataplot.latitude,c=dataplot.ocean_proximity,cmap="rainbow")

# %%
f=data_nadashte[data_nadashte["total_bedrooms"].isnull()]

# %%
f
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
f["ocean_proximity"]=f["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})
# Out:
# C:\Users\amiii\AppData\Local\Temp\ipykernel_1956\2529011264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f["ocean_proximity"]=f["ocean_proximity"].map({"NEAR BAY":0,'<1H OCEAN':1,'INLAND':2,'NEAR OCEAN':3,'ISLAND':4})

# %%
f
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
f["ocean_proximity"].value_counts()
# Out:
# 1    102
# 2     55
# 3     30
# 0     20
# Name: ocean_proximity, dtype: int64

# %%
datam=data.dropna()

# %%
datam_neearbay=datam[datam["ocean_proximity"]=="NEAR BAY"]

# %%
datam_neearbay
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                20.0       3306.0           503.0
# 19068    -122.47     38.29                14.0       3732.0           846.0
# 19069    -122.45     38.27                25.0       5024.0           881.0
# 19077    -122.49     38.27                 8.0       5092.0           988.0
# 19104    -122.51     38.17                 8.0       5875.0          1115.0
#
# ...

# %%
x1,y=datam_neearbay.households,datam_neearbay.total_bedrooms

# %%
x=st.add_constant(x1)

# %%
x
# Out:
#        const  households
# 0        1.0       126.0
# 1        1.0      1138.0
# 2        1.0       177.0
# 3        1.0       219.0
# 4        1.0       259.0
# ...      ...         ...
# 19067    1.0       460.0
# 19068    1.0       775.0
# 19069    1.0       838.0
# 19077    1.0       936.0
# 19104    1.0      1029.0
#
# [2270 rows x 2 columns]

# %%
res=st.OLS(y,x).fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         total_bedrooms   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 2.427e+05
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:25:35   Log-Likelihood:                -11317.
# No. Observations:                2270   AIC:                         2.264e+04
# Df Residuals:                    2268   BIC:                         2.265e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4189      1.287     -2.657      0.008      -5.942      -0.895
# ...
