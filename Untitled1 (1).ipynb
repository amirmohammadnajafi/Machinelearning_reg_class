# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mtl
from sklearn.cluster import KMeans
import seaborn as sns
from statsmodels import regression
import statsmodels.api as st
import statistics

# %%
data2=pd.read_csv(r"E:\train.csv")
data2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # preprocesing
# cod=data["colums"].replace([arayy],[number])

# %%
data=pd.read_csv(r"E:\salam.csv")
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         1         65.0     8450       1         1
# 1        2          20         1         80.0     9600       1         1
# 2        3          60         1         68.0    11250       1         2
# 3        4          70         1         60.0     9550       1         2
# 4        5          60         1         84.0    14260       1         2
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         1         62.0     7917       1         1
# 1456  1457          20         1         85.0    13175       1         1
# 1457  1458          70         1         66.0     9042       1         1
# 1458  1459          20         1         68.0     9717       1         1
# 1459  1460          20         1         75.0     9937       1         1
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# MSZoning       1460.0       1.340411      0.798309      1.0       1.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# ...               ...            ...           ...      ...        ...
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SaleType       1460.0       1.234932      0.804553      1.0       1.00
# SaleCondition  1460.0       1.350000      0.887870      1.0       1.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# ...

# %%
plt.hist(data.SalePrice)
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
data.corr()["LotFrontage"].sort_values()
# Out:
# BldgType       -0.471250
# PoolQC         -0.425638
# MSSubClass     -0.386347
# MSZoning       -0.248800
# GarageFinish   -0.223501
#                   ...
# LotArea         0.426095
# 1stFlrSF        0.457181
# LotFrontage     1.000000
# Utilities            NaN
# Fence                NaN
# Name: LotFrontage, Length: 79, dtype: float64

# %% [markdown]
# # null value

# %%
data1=data[["LotArea","LotFrontage"]]

# %%
data1.dropna(inplace=True)
# Out:
# E:\Users\amiii\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>]], dtype=object)

# %% [markdown]
# # togliere 0.02 la coda

# %%
r=data1["LotArea"].quantile(0.98)

# %%
data1=data1[data1["LotArea"]<=r]

# %%
data1.describe()
# Out:
#             LotArea  LotFrontage
# count   1177.000000   1177.00000
# mean    9280.004248     69.24554
# std     3387.834130     21.54145
# min     1300.000000     21.00000
# 25%     7350.000000     59.00000
# 50%     9196.000000     69.00000
# 75%    11096.000000     80.00000
# max    21780.000000    182.00000

# %% [markdown]
# # non cancello null value,faccio un reggresione sul null value per indovinarlo

# %%
x1,y=data1.LotArea,data1.LotFrontage

# %%
x=st.add_constant(x1)

# %%
reg=st.OLS(y,x).fit()

# %%
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            LotFrontage   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     970.0
# Date:                Sat, 10 Sep 2022   Prob (F-statistic):          9.44e-156
# Time:                        20:45:47   Log-Likelihood:                -4928.8
# No. Observations:                1177   AIC:                             9862.
# Df Residuals:                    1175   BIC:                             9872.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.5656      1.356     21.800      0.000      26.905      32.227
# ...

# %%
data[data["LotFrontage"].isna()]
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 7        8          60         1          NaN    10382       1         2
# 12      13          20         1          NaN    12968       1         3
# 14      15          20         1          NaN    10920       1         2
# 16      17          20         1          NaN    11241       1         2
# 24      25          20         1          NaN     8246       1         2
# ...    ...         ...       ...          ...      ...     ...       ...
# 1429  1430          20         1          NaN    12546       1         2
# 1431  1432         120         1          NaN     4928       1         2
# 1441  1442         120         2          NaN     4426       1         1
# 1443  1444          30         1          NaN     8854       1         1
# 1446  1447          20         1          NaN    26142       1         2
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
values={"LotFrontage":((data.LotArea*0.0043)+29.5656)}

# %%
data.fillna(value=values,inplace=True)

# %%
data.iloc[1429]
# Out:
# Id                  1430
# MSSubClass            20
# MSZoning               1
# LotFrontage      83.5134
# LotArea            12546
#                   ...
# MoSold                 4
# YrSold              2007
# SaleType               1
# SaleCondition          1
# SalePrice         182900
# Name: 1429, Length: 80, dtype: object

# %%
data.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260     1.340411    72.889438   10516.828082
# std     421.610009    42.300571     0.798309    37.177616    9981.264932
# min       1.000000    20.000000     1.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     1.000000    60.000000    7553.500000
# 50%     730.500000    50.000000     1.000000    70.000000    9478.500000
# 75%    1095.250000    70.000000     1.000000    81.837475   11601.500000
# max    1460.000000   190.000000     5.000000   737.603600  215245.000000
#
#             Street     LotShape  LandContour    Utilities    LotConfig  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      1.004110     1.408219     1.195205     1.000685     1.596575
# std       0.063996     0.582296     0.642010     0.026171     1.010359
# ...

# %%
data
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         1         65.0     8450       1         1
# 1        2          20         1         80.0     9600       1         1
# 2        3          60         1         68.0    11250       1         2
# 3        4          70         1         60.0     9550       1         2
# 4        5          60         1         84.0    14260       1         2
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         1         62.0     7917       1         1
# 1456  1457          20         1         85.0    13175       1         1
# 1457  1458          70         1         66.0     9042       1         1
# 1458  1459          20         1         68.0     9717       1         1
# 1459  1460          20         1         75.0     9937       1         1
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
data.corr()["SalePrice"].sort_values()
# Out:
# ExterQual      -0.666472
# KitchenQual    -0.659600
# BsmtQual       -0.644019
# PoolQC         -0.543811
# GarageFinish   -0.513105
#                   ...
# GarageCars      0.640409
# GrLivArea       0.708624
# OverallQual     0.790982
# SalePrice       1.000000
# Fence                NaN
# Name: SalePrice, Length: 79, dtype: float64

# %%
data.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260     1.340411    72.889438   10516.828082
# std     421.610009    42.300571     0.798309    37.177616    9981.264932
# min       1.000000    20.000000     1.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     1.000000    60.000000    7553.500000
# 50%     730.500000    50.000000     1.000000    70.000000    9478.500000
# 75%    1095.250000    70.000000     1.000000    81.837475   11601.500000
# max    1460.000000   190.000000     5.000000   737.603600  215245.000000
#
#             Street     LotShape  LandContour    Utilities    LotConfig  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      1.004110     1.408219     1.195205     1.000685     1.596575
# std       0.063996     0.582296     0.642010     0.026171     1.010359
# ...

# %%
corr2 = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corr2, vmax=.8, square=True);

# %%
x3=data[["GarageCars","GrLivArea","OverallQual","ExterQual","KitchenQual"]]

# %%
x3
# Out:
#       GarageCars  GrLivArea  OverallQual  ExterQual  KitchenQual
# 0              2       1710            7          1            2
# 1              2       1262            6          2            3
# 2              2       1786            7          1            2
# 3              3       1717            7          2            2
# 4              3       2198            8          1            2
# ...          ...        ...          ...        ...          ...
# 1455           2       1647            6          2            3
# 1456           2       2073            6          2            3
# 1457           1       2340            7          0            2
# 1458           1       1078            5          2            2
# 1459           1       1256            5          1            3
#
# [1460 rows x 5 columns]

# %%
x4=st.add_constant(x3)

# %%
x4
y=data.SalePrice

# %%
reg2=st.OLS(y,x4).fit()

# %%
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     932.9
# Date:                Sat, 10 Sep 2022   Prob (F-statistic):               0.00
# Time:                        21:01:02   Log-Likelihood:                -17495.
# No. Observations:                1460   AIC:                         3.500e+04
# Df Residuals:                    1454   BIC:                         3.503e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        2.786e+04   1.16e+04      2.406      0.016    5144.285    5.06e+04
# ...

# %% [markdown]
# predict=GarageCars*1.711e+04+GrLivArea*51.0029+OverallQual*1.83e+04+ExterQual*-1.461e+04+KitchenQual*-1.708e+04+2.786e+04
